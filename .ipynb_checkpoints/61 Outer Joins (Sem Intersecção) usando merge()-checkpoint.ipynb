# %%
import pandas as pd

# %%
df_2008 = pd.read_csv('ath_2008.csv')

# %%
df_2012 = pd.read_csv('ath_2012.csv')

# %%
df_2008.head()
# Out:
#               Athlete  Gold  Silver  Bronze
# 0    ABAKUMOVA, Maria     0       1       0
# 1  ABEYLEGESSE, Elvan     0       2       0
# 2  ALEKNA, Virgilijus     0       0       1
# 3      ALEXEEV, Denis     0       0       1
# 4     ANTONOVA, Olena     0       0       1

# %%
df_merge_outer = df_2008.merge(df_2012, how='outer', on='Athlete', suffixes=('_2008', '_2012'), indicator=True)

display(df_merge_outer)
# Out:
#                      Athlete  Gold_2008  Silver_2008  Bronze_2008  Gold_2012  \
# 0           ABAKUMOVA, Maria        0.0          1.0          0.0        NaN
# 1         ABEYLEGESSE, Elvan        0.0          2.0          0.0        NaN
# 2         ALEKNA, Virgilijus        0.0          0.0          1.0        NaN
# 3             ALEXEEV, Denis        0.0          0.0          1.0        NaN
# 4            ANTONOVA, Olena        0.0          0.0          1.0        NaN
# ..                       ...        ...          ...          ...        ...
# 293             WEIR, Warren        NaN          NaN          NaN        0.0
# 294            WELLS, Kellie        NaN          NaN          NaN        0.0
# 295         WILLIAMS, Lauryn        NaN          NaN          NaN        1.0
# 296  WILLIAMS-MILLS, Novlene        NaN          NaN          NaN        0.0
# 297        WLODARCZYK, Anita        NaN          NaN          NaN        1.0
#
#      Silver_2012  Bronze_2012      _merge
# ...

# %%
df_merge_outer._merge.value_counts()
# Out:
# right_only    139
# left_only     127
# both           32
# Name: _merge, dtype: int64

# %%
# VAMOS ACESSAR A COLUNA '_merge'
# != "both"   -> Trazer todos os valores que não são comuns.

df_merge_outer_sem_Interc = df_merge_outer.loc[df_merge_outer._merge != "both"]

#display(df_merge_outer_sem_Interc )


# ELIMINAMOS AS 32 INTERCESSÕES
df_merge_outer_sem_Interc._merge.value_counts()
# Out:
# right_only    139
# left_only     127
# both            0
# Name: _merge, dtype: int64
