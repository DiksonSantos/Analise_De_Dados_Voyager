# %%
import pandas as pd

# %%
df = pd.read_csv("campeonato-brasileiro-full.csv")

# %%
df.head()
# Out:
#   Rodada        Data Horário      Dia     Mandante    Visitante    Vencedor  \
# 0      1  2000-07-29   16h00   Sábado   Fluminense        Bahia  Fluminense
# 1      1  2000-07-29   16h00   Sábado        Vasco        Sport       Sport
# 2      1  2000-07-29   16h00   Sábado      Vitória    Palmeiras     Vitória
# 3      1  2000-07-30   17h00  Domingo  Botafogo-RJ  Atlético-MG           -
# 4      1  2000-07-30   18h30  Domingo    Juventude     Flamengo           -
#
#             Arena  Mandante Placar  Visitante Placar Estado Mandante  \
# 0        Maracanã                2                 0              RJ
# 1    São Januário                0                 2              RJ
# 2        Barradão                4                 1              ES
# 3    Caio Martins                0                 0              RJ
# 4  Alfredo Jaconi                1                 1              RS
#
#   Estado Visitante Estado Vencedor
# 0               BA              RJ
# ...

# %%
# EXCLUIR COLUNA 'ID':
# implace = True -> Confirma a exclusão.
df.drop(columns='ID', inplace=True)

# %%
df.head(2)
# Out:
#   Rodada        Data Horário     Dia    Mandante Visitante    Vencedor  \
# 0      1  2000-07-29   16h00  Sábado  Fluminense     Bahia  Fluminense
# 1      1  2000-07-29   16h00  Sábado       Vasco     Sport       Sport
#
#           Arena  Mandante Placar  Visitante Placar Estado Mandante  \
# 0      Maracanã                2                 0              RJ
# 1  São Januário                0                 2              RJ
#
#   Estado Visitante Estado Vencedor
# 0               BA              RJ
# 1               PE              PE

# %%
# 
df.drop(columns=['Dia','Arena'], inplace=True)

# %%
# COLUNAS EXCLUIDAS (3):
df.head()
# Out:
#   Rodada        Data Horário     Mandante    Visitante    Vencedor  \
# 0      1  2000-07-29   16h00   Fluminense        Bahia  Fluminense
# 1      1  2000-07-29   16h00        Vasco        Sport       Sport
# 2      1  2000-07-29   16h00      Vitória    Palmeiras     Vitória
# 3      1  2000-07-30   17h00  Botafogo-RJ  Atlético-MG           -
# 4      1  2000-07-30   18h30    Juventude     Flamengo           -
#
#    Mandante Placar  Visitante Placar Estado Mandante Estado Visitante  \
# 0                2                 0              RJ               BA
# 1                0                 2              RJ               PE
# 2                4                 1              ES               SP
# 3                0                 0              RJ               MG
# 4                1                 1              RS               RJ
#
#   Estado Vencedor
# 0              RJ
# 1              PE
# 2              ES
# 3               -
# 4               -

# %%
# OUTRO MÉTODO DE EXCLUSÃO:
del df['Vencedor']

# %%
df.head()
# Out:
#   Rodada        Data Horário     Mandante    Visitante  Mandante Placar  \
# 0      1  2000-07-29   16h00   Fluminense        Bahia                2
# 1      1  2000-07-29   16h00        Vasco        Sport                0
# 2      1  2000-07-29   16h00      Vitória    Palmeiras                4
# 3      1  2000-07-30   17h00  Botafogo-RJ  Atlético-MG                0
# 4      1  2000-07-30   18h30    Juventude     Flamengo                1
#
#    Visitante Placar Estado Mandante Estado Visitante Estado Vencedor
# 0                 0              RJ               BA              RJ
# 1                 2              RJ               PE              PE
# 2                 1              ES               SP              ES
# 3                 0              RJ               MG               -
# 4                 1              RS               RJ               -
