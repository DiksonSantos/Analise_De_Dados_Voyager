# %%
import pandas as pd
import os
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("campeonato-brasileiro-full.csv")

# %%
display(df)
# Out:
#         ID Rodada        Data Horário           Dia       Mandante  \
# 0        1      1  2000-07-29   16h00        Sábado     Fluminense
# 1        2      1  2000-07-29   16h00        Sábado          Vasco
# 2        3      1  2000-07-29   16h00        Sábado        Vitória
# 3        4      1  2000-07-30   17h00       Domingo    Botafogo-RJ
# 4        5      1  2000-07-30   18h30       Domingo      Juventude
# ...    ...    ...         ...     ...           ...            ...
# 8314  8315     38  2021-02-25   21:30  Quinta-Feira  Internacional
# 8315  8316     38  2021-02-25   21:30  Quinta-Feira          Bahia
# 8316  8317     38  2021-02-25   21:30  Quinta-Feira   Athlético-PR
# 8317  8318     38  2021-02-25   21:30  Quinta-Feira          Ceará
# 8318  8319     38  2021-02-25   21:30  Quinta-Feira    Atlético-GO
#
#         Visitante      Vencedor                      Arena  Mandante Placar  \
# 0           Bahia    Fluminense                   Maracanã                2
# ...

# %%
cwd = os.getcwd()

# %%
print(cwd)
# Out:
# /home/dikson/CURSOS_ALL/Metodo Voyager DS

# %%
print('Ola Mundo')
# Out:
# Ola Mundo

# %%
df
# Out:
#         ID Rodada        Data Horário           Dia       Mandante  \
# 0        1      1  2000-07-29   16h00        Sábado     Fluminense
# 1        2      1  2000-07-29   16h00        Sábado          Vasco
# 2        3      1  2000-07-29   16h00        Sábado        Vitória
# 3        4      1  2000-07-30   17h00       Domingo    Botafogo-RJ
# 4        5      1  2000-07-30   18h30       Domingo      Juventude
# ...    ...    ...         ...     ...           ...            ...
# 8314  8315     38  2021-02-25   21:30  Quinta-Feira  Internacional
# 8315  8316     38  2021-02-25   21:30  Quinta-Feira          Bahia
# 8316  8317     38  2021-02-25   21:30  Quinta-Feira   Athlético-PR
# 8317  8318     38  2021-02-25   21:30  Quinta-Feira          Ceará
# 8318  8319     38  2021-02-25   21:30  Quinta-Feira    Atlético-GO
#
#         Visitante      Vencedor                      Arena  Mandante Placar  \
# 0           Bahia    Fluminense                   Maracanã                2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8319 entries, 0 to 8318
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                8319 non-null   int64
#  1   Rodada            8319 non-null   object
#  2   Data              8319 non-null   object
#  3   Horário           7962 non-null   object
#  4   Dia               8319 non-null   object
#  5   Mandante          8319 non-null   object
#  6   Visitante         8319 non-null   object
#  7   Vencedor          8319 non-null   object
#  8   Arena             8319 non-null   object
#  9   Mandante Placar   8319 non-null   int64
#  10  Visitante Placar  8319 non-null   int64
#  11  Estado Mandante   8319 non-null   object
#  12  Estado Visitante  8319 non-null   object
#  13  Estado Vencedor   8319 non-null   object
# dtypes: int64(3), object(11)
# memory usage: 910.0+ KB

# %%
df.describe()
# Out:
#                 ID  Mandante Placar  Visitante Placar
# count  8319.000000      8319.000000       8319.000000
# mean   4160.000000         1.588292          1.053492
# std    2401.632778         1.245473          1.040604
# min       1.000000         0.000000          0.000000
# 25%    2080.500000         1.000000          0.000000
# 50%    4160.000000         1.000000          1.000000
# 75%    6239.500000         2.000000          2.000000
# max    8319.000000         7.000000          7.000000

# %%
# Para valores Não Numericos:
df.describe(include="O")
# Out:
#        Rodada        Data Horário      Dia   Mandante   Visitante Vencedor  \
# count    8319        8319    7962     8319       8319        8319     8319
# unique     53        1811      59       12         61          63       59
# top        16  2008-07-06   16h00  Domingo  São Paulo  Fluminense        -
# freq      222          15    1804     3807        393         392     2148
#
#            Arena Estado Mandante Estado Visitante Estado Vencedor
# count       8319            8319             8319            8319
# unique       114              15               15              16
# top     Maracanã              SP               SP               -
# freq         626            2136             2136            2148

# %%
# 
df.describe(include="all")
# Out:
#                  ID Rodada        Data Horário      Dia   Mandante  \
# count   8319.000000   8319        8319    7962     8319       8319
# unique          NaN     53        1811      59       12         61
# top             NaN     16  2008-07-06   16h00  Domingo  São Paulo
# freq            NaN    222          15    1804     3807        393
# mean    4160.000000    NaN         NaN     NaN      NaN        NaN
# std     2401.632778    NaN         NaN     NaN      NaN        NaN
# min        1.000000    NaN         NaN     NaN      NaN        NaN
# 25%     2080.500000    NaN         NaN     NaN      NaN        NaN
# 50%     4160.000000    NaN         NaN     NaN      NaN        NaN
# 75%     6239.500000    NaN         NaN     NaN      NaN        NaN
# max     8319.000000    NaN         NaN     NaN      NaN        NaN
#
#          Visitante Vencedor     Arena  Mandante Placar  Visitante Placar  \
# count         8319     8319      8319      8319.000000       8319.000000
# ...

# %%
# Mostra quantidade de linhas e colunas no DataFrame:
df.shape
# Out:
# (8319, 14)

# %%
# Empacotando Linhas & Colunas
linha, coluna = df.shape

# %%
print(f"Linhas:",linha,"\nColunas:",coluna)
# Out:
# Linhas: 8319
# Colunas: 14

# %%
# Mostra o Numero de Linhas do Objeto:
df.size
# Out:
# 116466

# %%
# COMANDO UTIL PARA VER TODAS AS COLUNAS:
# Mostra só as 5 priemiras Linhas do DataFrame:
df.head(5)
# Out:
#    ID Rodada        Data Horário      Dia     Mandante    Visitante  \
# 0   1      1  2000-07-29   16h00   Sábado   Fluminense        Bahia
# 1   2      1  2000-07-29   16h00   Sábado        Vasco        Sport
# 2   3      1  2000-07-29   16h00   Sábado      Vitória    Palmeiras
# 3   4      1  2000-07-30   17h00  Domingo  Botafogo-RJ  Atlético-MG
# 4   5      1  2000-07-30   18h30  Domingo    Juventude     Flamengo
#
#      Vencedor           Arena  Mandante Placar  Visitante Placar  \
# 0  Fluminense        Maracanã                2                 0
# 1       Sport    São Januário                0                 2
# 2     Vitória        Barradão                4                 1
# 3           -    Caio Martins                0                 0
# 4           -  Alfredo Jaconi                1                 1
#
#   Estado Mandante Estado Visitante Estado Vencedor
# 0              RJ               BA              RJ
# 1              RJ               PE              PE
# ...

# %%
df.min()
# Out:
# ID                           1
# Rodada                       1
# Data                2000-07-29
# Dia                    Domingo
# Mandante            América-MG
# Visitante           América-MG
# Vencedor                     -
# Arena               1º de Maio
# Mandante Placar              0
# Visitante Placar             0
# Estado Mandante             AL
# Estado Visitante            AL
# Estado Vencedor              -
# dtype: object

# %%
df.mean()
# Out:
# ID                  4160.000000
# Mandante Placar        1.588292
# Visitante Placar       1.053492
# dtype: float64

# %%
df.isnull()
# Out:
#          ID  Rodada   Data  Horário    Dia  Mandante  Visitante  Vencedor  \
# 0     False   False  False    False  False     False      False     False
# 1     False   False  False    False  False     False      False     False
# 2     False   False  False    False  False     False      False     False
# 3     False   False  False    False  False     False      False     False
# 4     False   False  False    False  False     False      False     False
# ...     ...     ...    ...      ...    ...       ...        ...       ...
# 8314  False   False  False    False  False     False      False     False
# 8315  False   False  False    False  False     False      False     False
# 8316  False   False  False    False  False     False      False     False
# 8317  False   False  False    False  False     False      False     False
# 8318  False   False  False    False  False     False      False     False
#
#       Arena  Mandante Placar  Visitante Placar  Estado Mandante  \
# ...

# %%
df.keys()
# Out:
# Index(['ID', 'Rodada', 'Data', 'Horário', 'Dia', 'Mandante', 'Visitante',
#        'Vencedor', 'Arena', 'Mandante Placar', 'Visitante Placar',
#        'Estado Mandante', 'Estado Visitante', 'Estado Vencedor'],
#       dtype='object')

# %%
#ENCADEAMENTO DE METODOS:
df.mean().sort_values().head(3)
# Out:
# Visitante Placar       1.053492
# Mandante Placar        1.588292
# ID                  4160.000000
# dtype: float64

# %%
# VISUALISA TODAS AS COLUNAS
# df.head()

# SELECIONA UMA DAS COLUNAS:
df["Mandante Placar"]   # Para palavras separadas

# OU
# display(df["Visitante"])

# OU
# df.Visitante
# Out:
# 0       2
# 1       0
# 2       4
# 3       0
# 4       1
#        ..
# 8314    0
# 8315    2
# 8316    2
# 8317    2
# 8318    3
# Name: Mandante Placar, Length: 8319, dtype: int64

# %%
# ACESSANDO MAIS DE UMA COLUNA AO MESMO TEMPO

df[['Estado Visitante', "Estado Vencedor"]]
# Out:
#      Estado Visitante Estado Vencedor
# 0                  BA              RJ
# 1                  PE              PE
# 2                  SP              ES
# 3                  MG               -
# 4                  RJ               -
# ...               ...             ...
# 8314               SP               -
# 8315               SP              BA
# 8316               PE              PR
# 8317               RJ              CE
# 8318               PR              GO
#
# [8319 rows x 2 columns]

# %%
# CRIA NOVO DF COM APENAS ALGUMAS COLUNAS (SELECIONADAS)
df_2 = df[['Estado Visitante', "Estado Vencedor", "Estado Mandante"]]
display(df_2)
# Out:
#      Estado Visitante Estado Vencedor Estado Mandante
# 0                  BA              RJ              RJ
# 1                  PE              PE              RJ
# 2                  SP              ES              ES
# 3                  MG               -              RJ
# 4                  RJ               -              RS
# ...               ...             ...             ...
# 8314               SP               -              RS
# 8315               SP              BA              BA
# 8316               PE              PR              PR
# 8317               RJ              CE              CE
# 8318               PR              GO              GO
#
# [8319 rows x 3 columns]

# %%
display(df)
# Out:
#         ID Rodada        Data Horário           Dia       Mandante  \
# 0        1      1  2000-07-29   16h00        Sábado     Fluminense
# 1        2      1  2000-07-29   16h00        Sábado          Vasco
# 2        3      1  2000-07-29   16h00        Sábado        Vitória
# 3        4      1  2000-07-30   17h00       Domingo    Botafogo-RJ
# 4        5      1  2000-07-30   18h30       Domingo      Juventude
# ...    ...    ...         ...     ...           ...            ...
# 8314  8315     38  2021-02-25   21:30  Quinta-Feira  Internacional
# 8315  8316     38  2021-02-25   21:30  Quinta-Feira          Bahia
# 8316  8317     38  2021-02-25   21:30  Quinta-Feira   Athlético-PR
# 8317  8318     38  2021-02-25   21:30  Quinta-Feira          Ceará
# 8318  8319     38  2021-02-25   21:30  Quinta-Feira    Atlético-GO
#
#         Visitante      Vencedor                      Arena  Mandante Placar  \
# 0           Bahia    Fluminense                   Maracanã                2
# ...
