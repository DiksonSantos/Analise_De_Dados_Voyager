# %%
import pandas as pd

# %%
df = pd.read_csv('campeonato-brasileiro-full.csv')

# %%
# DESIGNANDO UMA COLUNA DO DF PARA SER O NOVO INDEX


df2 = pd.read_csv('campeonato-brasileiro-full.csv', index_col="Arena")

# %%
df2.head()
# Out:
#                 ID Rodada        Data Horário      Dia     Mandante  \
# Arena
# Maracanã         1      1  2000-07-29   16h00   Sábado   Fluminense
# São Januário     2      1  2000-07-29   16h00   Sábado        Vasco
# Barradão         3      1  2000-07-29   16h00   Sábado      Vitória
# Caio Martins     4      1  2000-07-30   17h00  Domingo  Botafogo-RJ
# Alfredo Jaconi   5      1  2000-07-30   18h30  Domingo    Juventude
#
#                   Visitante    Vencedor  Mandante Placar  Visitante Placar  \
# Arena
# Maracanã              Bahia  Fluminense                2                 0
# São Januário          Sport       Sport                0                 2
# Barradão          Palmeiras     Vitória                4                 1
# Caio Martins    Atlético-MG           -                0                 0
# Alfredo Jaconi     Flamengo           -                1                 1
#
#                Estado Mandante Estado Visitante Estado Vencedor
# Arena
# ...

# %%
# EXCLUINDO UMA COLUNA MENCIONANDO O NOME DA MESMA:
df2.drop(labels='Maracanã', axis=0, inplace=True)

# %%
# Linha Maracanã Excluida:
df2.head()
# Out:
#                 ID Rodada        Data Horário      Dia     Mandante  \
# Arena
# São Januário     2      1  2000-07-29   16h00   Sábado        Vasco
# Barradão         3      1  2000-07-29   16h00   Sábado      Vitória
# Caio Martins     4      1  2000-07-30   17h00  Domingo  Botafogo-RJ
# Alfredo Jaconi   5      1  2000-07-30   18h30  Domingo    Juventude
# Brinco de Ouro   6      1  2000-07-30   16h00  Domingo      Guarani
#
#                   Visitante Vencedor  Mandante Placar  Visitante Placar  \
# Arena
# São Januário          Sport    Sport                0                 2
# Barradão          Palmeiras  Vitória                4                 1
# Caio Martins    Atlético-MG        -                0                 0
# Alfredo Jaconi     Flamengo        -                1                 1
# Brinco de Ouro   Santa Cruz        -                0                 0
#
#                Estado Mandante Estado Visitante Estado Vencedor
# Arena
# ...
