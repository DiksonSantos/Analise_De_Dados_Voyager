# %%
import pandas as pd

# %%
df = pd.read_csv("campeonato-brasileiro-full.csv")

# %%
df.head()
# Out:
#    ID Rodada        Data Horário      Dia     Mandante    Visitante  \
# 0   1      1  2000-07-29   16h00   Sábado   Fluminense        Bahia
# 1   2      1  2000-07-29   16h00   Sábado        Vasco        Sport
# 2   3      1  2000-07-29   16h00   Sábado      Vitória    Palmeiras
# 3   4      1  2000-07-30   17h00  Domingo  Botafogo-RJ  Atlético-MG
# 4   5      1  2000-07-30   18h30  Domingo    Juventude     Flamengo
#
#      Vencedor           Arena  Mandante Placar  Visitante Placar  \
# 0  Fluminense        Maracanã                2                 0
# 1       Sport    São Januário                0                 2
# 2     Vitória        Barradão                4                 1
# 3           -    Caio Martins                0                 0
# 4           -  Alfredo Jaconi                1                 1
#
#   Estado Mandante Estado Visitante Estado Vencedor
# 0              RJ               BA              RJ
# 1              RJ               PE              PE
# ...

# %%
# Linhas x Colunas
df.shape
# Out:
# (8319, 14)

# %%
# Pega Apenas 30 Linhas do DataFeame inteiro
df_sample = df.sample(30)

# %%
df_sample.tail(30)
# Out:
#         ID Rodada        Data Horário            Dia       Mandante  \
# 1246  1247     17  2003-07-09   20h30   Quarta-feira          Bahia
# 7280  7281     11  2018-06-09   16:00         Sábado   Athlético-PR
# 3252  3253     26  2007-09-15   18h10         Sábado          Goiás
# 5114  5115     22  2012-09-05   19h30   Quarta-feira       Flamengo
# 7629  7630      8  2019-06-08   19:30         Sábado          Ceará
# 7233  7234      6  2018-05-20   16:00        Domingo     América-MG
# 5904  5905     25  2014-09-28   16h00        Domingo          Bahia
# 1366  1367     27  2003-08-20   21h40   Quarta-feira    Corinthians
# 1349  1350     25  2003-08-10   16h00        Domingo    Atlético-MG
# 3866  3867     11  2009-07-16   21h00   Quinta-feira    Atlético-MG
# 4988  4989      9  2012-07-15   18h30        Domingo          Vasco
# 7268  7269     10  2018-06-05   21:30    Terça-feira      São Paulo
# 1086  1087      3  2003-04-13   18h00        Domingo       Flamengo
# ...

# %%
# Apenas 30 Linhas (14 Colunas)
df_sample.shape
# Out:
# (30, 14)

# %%
# Definir A Coluna "Rodada" Como a primeira Coluna (Index) 
df_sample.set_index("Rodada")
# Out:
#           ID        Data Horário            Dia       Mandante      Visitante  \
# Rodada
# 17      1247  2003-07-09   20h30   Quarta-feira          Bahia        Guarani
# 11      7281  2018-06-09   16:00         Sábado   Athlético-PR      São Paulo
# 26      3253  2007-09-15   18h10         Sábado          Goiás        Náutico
# 22      5115  2012-09-05   19h30   Quarta-feira       Flamengo    Ponte Preta
# 8       7630  2019-06-08   19:30         Sábado          Ceará          Bahia
# 6       7234  2018-05-20   16:00        Domingo     América-MG    Botafogo-rj
# 25      5905  2014-09-28   16h00        Domingo          Bahia       Flamengo
# 27      1367  2003-08-20   21h40   Quarta-feira    Corinthians          Vasco
# 25      1350  2003-08-10   16h00        Domingo    Atlético-MG    Corinthians
# 11      3867  2009-07-16   21h00   Quinta-feira    Atlético-MG      São Paulo
# 9       4989  2012-07-15   18h30        Domingo          Vasco    Atlético-GO
# ...

# %%
# DEFININDO MAIS DE UM INDEX:
df_sample.set_index(["Dia", "Visitante Placar"], inplace = True)

# %%
df_sample.head()
# Out:
#                                  ID Rodada        Data Horário      Mandante  \
# Dia          Visitante Placar
# Quarta-feira 0                 1247     17  2003-07-09   20h30         Bahia
# Sábado       1                 7281     11  2018-06-09   16:00  Athlético-PR
#              3                 3253     26  2007-09-15   18h10         Goiás
# Quarta-feira 1                 5115     22  2012-09-05   19h30      Flamengo
# Sábado       0                 7630      8  2019-06-08   19:30         Ceará
#
#                                  Visitante     Vencedor                Arena  \
# Dia          Visitante Placar
# Quarta-feira 0                     Guarani        Bahia           Fonte Nova
# Sábado       1                   São Paulo    São Paulo     Arena da Baixada
#              3                     Náutico      Náutico        Serra Dourada
# Quarta-feira 1                 Ponte Preta  Ponte Preta  Raulino de Oliveira
# ...

# %%
# ORGANIZAR A ORDEM DOS INDEXEs

# Define 'False' e 'True' para (neste caso) as duas colunas respectivamente
df_sample.sort_index(ascending=[False, True], inplace=True)

# A coluna 'Dia' passou para o lado esquerdo melhorou a visualização.

# %%
df_sample.head(10)
# Out:
#                                   ID Rodada        Data Horário      Mandante  \
# Dia           Visitante Placar
# Terça-feira   0                 7269     10  2018-06-05   21:30     São Paulo
# Sábado        0                 7630      8  2019-06-08   19:30         Ceará
#               0                 2632      2  2006-04-22   18h10    Fluminense
#               0                 6541     13  2016-07-02   18:30  Athlético-PR
#               0                 5461     19  2013-09-07   18:30        Santos
#               1                 7281     11  2018-06-09   16:00  Athlético-PR
#               2                 5251     36  2012-11-17   19h30      Coritiba
#               3                 3253     26  2007-09-15   18h10         Goiás
# Segunda-feira 3                 6699     28  2016-10-03   20:00    Santa Cruz
# Quinta-feira  0                 3867     11  2009-07-16   21h00   Atlético-MG
#
# ...

# %%
# Desfazendo as mudanças no Index
df_sample.reset_index(inplace=True)

# %%
df_sample.head()
# Out:
#            Dia  Visitante Placar    ID Rodada        Data Horário  \
# 0  Terça-feira                 0  7269     10  2018-06-05   21:30
# 1       Sábado                 0  7630      8  2019-06-08   19:30
# 2       Sábado                 0  2632      2  2006-04-22   18h10
# 3       Sábado                 0  6541     13  2016-07-02   18:30
# 4       Sábado                 0  5461     19  2013-09-07   18:30
#
#        Mandante      Visitante      Vencedor             Arena  \
# 0     São Paulo  Internacional             -           Morumbi
# 1         Ceará          Bahia             -          Castelão
# 2    Fluminense          Goiás    Fluminense          Maracanã
# 3  Athlético-PR     América-MG  Athlético-PR  Arena da Baixada
# 4        Santos          Goiás        Santos      Vila Belmiro
#
#    Mandante Placar Estado Mandante Estado Visitante Estado Vencedor
# 0                0              SP               RS               -
# ...

# %%
#
df_sample.set_index(["Dia", "Mandante Placar"], inplace = True)

# %%
# Trocamos a Ordem de Mandante_P x Dia
df_sample.swaplevel()
# Out:
#                                Visitante Placar    ID Rodada        Data  \
# Mandante Placar Dia
# 0               Terça-feira                   0  7269     10  2018-06-05
#                 Sábado                        0  7630      8  2019-06-08
# 1               Sábado                        0  2632      2  2006-04-22
#                 Sábado                        0  6541     13  2016-07-02
#                 Sábado                        0  5461     19  2013-09-07
# 0               Sábado                        1  7281     11  2018-06-09
# 1               Sábado                        2  5251     36  2012-11-17
# 0               Sábado                        3  3253     26  2007-09-15
# 2               Segunda-feira                 3  6699     28  2016-10-03
#                 Quinta-feira                  0  3867     11  2009-07-16
# 3               Quinta-feira                  2  5207     31  2012-10-18
# 2               Quarta-feira                  0  1247     17  2003-07-09
# ...

# %%
# Original mode
df_sample.head()
# Out:
#                              Visitante Placar    ID Rodada        Data  \
# Dia         Mandante Placar
# Terça-feira 0                               0  7269     10  2018-06-05
# Sábado      0                               0  7630      8  2019-06-08
#             1                               0  2632      2  2006-04-22
#             1                               0  6541     13  2016-07-02
#             1                               0  5461     19  2013-09-07
#
#                             Horário      Mandante      Visitante  \
# Dia         Mandante Placar
# Terça-feira 0                 21:30     São Paulo  Internacional
# Sábado      0                 19:30         Ceará          Bahia
#             1                 18h10    Fluminense          Goiás
#             1                 18:30  Athlético-PR     América-MG
#             1                 18:30        Santos          Goiás
#
#                                  Vencedor             Arena Estado Mandante  \
# ...
